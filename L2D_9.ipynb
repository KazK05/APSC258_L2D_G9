# %% [markdown]
# # Lab Part 4
# # Neural Network Model Template
#
# This file contains boilerplate for creating a neural network. Designing a neural network is quite difficult and requires a lot of time to set up data processing pipelines and image processing. As well as making sure that the tensors and datasets are in the correct formats. This file contains all that you need to make your very own neural network.

# %%
# Config Parameters for the model
# Set the batch size here
# increase for systems with more memory, 32 should be enough for most systems
BATCH_SIZE = 32

# %% [markdown]
# ## Part 1: Unpack our data
# All we do is install 7zip and then use pyunpack to extract the files. This saves datasets to /notebooks which is a directory on Paperspace Gradient that is acceptable by python.

# %%
# Mount Google Drive
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)

import zipfile

# dataset file name
data_file = "final_data_turnboost" # change this to your dataset file name

zip_ref = zipfile.ZipFile("/content/gdrive/MyDrive/final_data_turnboost.zip", 'r')
zip_ref.extractall()
zip_ref.close()

data_dir = '/content/' + data_file + '/'
train_dir = data_dir + 'train/' # directory for training images
test_dir = data_dir + 'test/' # directory for test images we use the test images to make sure our model is working well
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Part 3: Loading in the data
# ### Dealing with images
# Our image files that we are using for training are pretty large. Your computer may crash if we loaded them all at once so instead we will just store where the images are stored. Later you will see how we can automatically load these files when we run our code. One thing to note is that each image file is named (somenumber).jpg that number is the number of milliseconds since 1 January 1970 (Unix Time) when the file was recorded. This means that we will never have any overlapping files. Unfortunately this does mean we will have to sort the times from smallest to largest to make sure that they correspond with the steering angles which are recorded sequentially.
#
# ### Dealing with steering angles
# We store our steering values as a csv (comma separated values) file. Python has a built in csv module so we can easily use it to load in all the steering values into a list. These don't take up much ram so it doesn't matter if we load them all in at once. They're just numbers after all.
#
# ### Making sure the files line up
# Since we sort our images, and the csv file is read in line by line the files will line up with their correct steering angles. It looks something like this. If we mess this up then the data being fed into your network would be totally incoherent. Garbage in Garbage out.
#
# train_img =   | image 1    | image 2    | image 3    | image 4    | image 5    |...
#
# train_steer = | steering 1 | steering 2 | steering 3 | steering 4 | steering 5 |...

# %%
import csv
import os
# lets make a function that loads the images and labels
def load_data(directory):
    image__paths = []
    for file in os.listdir(directory): # for each file in the directory
        if file.endswith(".png"): # if the file is an image
            image__paths.append(directory + file) # add the image path to the list
    print(image__paths)
    # now our files are in the train list we need to sort them from smallest file name to largest. The file name is the exact time the image was taken.
    image__paths.sort(key=lambda x: int(x.split('/')[-1][:-4].split('_')[0][:])) # the lambda function returns the numbers in the file name
    print(image__paths)
    # now we get the steering angles
    steering_angles = [] # create a list to store the steering angles
    for angle in image__paths: # for each row in the csv file
        steering_angles.append(float(angle.split('/')[-1][:-4].split('_')[-1].replace('-','.'))) # add the steering angle to the list
    print(steering_angles)
    return image__paths, steering_angles # return the image paths and steering angles

# We call our load data function to get the image paths and steering angles
train_img, train_steer = load_data(train_dir) # load the training data
test_img, test_steer = load_data(test_dir) # load the test data
# Out:
# ['/content/final_data_turnboost/train/4188_68-774.png', '/content/final_data_turnboost/train/956_120-536.png', '/content/final_data_turnboost/train/488_dup_159-545.png', '/content/final_data_turnboost/train/10647_85-192.png', '/content/final_data_turnboost/train/1867_82-128.png', '/content/final_data_turnboost/train/8129_27-063.png', '/content/final_data_turnboost/train/2220_76-497.png', '/content/final_data_turnboost/train/7062_101-575.png', '/content/final_data_turnboost/train/6216_62-334.png', '/content/final_data_turnboost/train/8536_149-978.png', '/content/final_data_turnboost/train/1415_85-469.png', '/content/final_data_turnboost/train/2561_102-384.png', '/content/final_data_turnboost/train/11949_70-89.png', '/content/final_data_turnboost/train/6769_43-806.png', '/content/final_data_turnboost/train/3631_39-092.png', '/content/final_data_turnboost/train/8938_89-73.png', '/content/final_data_turnboost/train/8043_103-384.png', '/content/final_data_turnboost/train/1807_110-741.png', '/content/final_data_turnboost/train/242_113-606.png', '/content/final_data_turnboost/train/8234_60-521.png', '/content/final_data_turnboost/train/1489_dup_165.png', '/content/final_data_turnboost/train/4586_74-573.png', '/content/final_data_turnboost/train/3357_dup_155-794.png', '/content/final_data_turnboost/train/6362_65-615.png', '/content/final_data_turnboost/train/3762_107.png', '/content/final_data_turnboost/train/492_126-665.png', '/content/final_data_turnboost/train/3685_59-441.png', '/content/final_data_turnboost/train/5433_97-645.png', '/content/final_data_turnboost/train/6021_139-41.png', '/content/final_data_turnboost/train/8111_88-527.png', '/content/final_data_turnboost/train/9370_34-18.png', '/content/final_data_turnboost/train/338_77-307.png', '/content/final_data_turnboost/train/707_123-389.png', '/content/final_data_turnboost/train/9738_37-052.png', '/content/final_data_turnboost/train/4965_134-293.png', '/content/final_data_turnboost/train/971_84-433.png', '/content/final_data_turnboost/train/9415_150-656.png', '/content/final_data_turnboost/train/9367_31-556.png', '/content/final_data_turnboost/train/2635_127-757.png', '/content/final_data_turnboost/train/3897_100-065.png', '/content/final_data_turnboost/train/4898_98-479.png', '/content/final_data_turnboost/train/9089_123-026.png', '/content/final_data_turnboost/train/8380_dup_164-485.png', '/content/final_data_turnboost/train/7376_22-668.png', '/content/final_data_turnboost/train/6251_30-836.png', '/content/final_data_turnboost/train/6966_82-32.png', '/content/final_data_turnboost/train/3806_113-354.png', '/content/final_data_turnboost/train/4295_dup_24-37.png', '/content/final_data_turnboost/train/5495_54-062.png', '/content/final_data_turnboost/train/4335_dup_21-642.png', '/content/final_data_turnboost/train/3046_53-049.png', '/content/final_data_turnboost/train/7068_92-537.png', '/content/final_data_turnboost/train/10890_46-449.png', '/content/final_data_turnboost/train/4922_144-85.png', '/content/final_data_turnboost/train/2140_53-948.png', '/content/final_data_turnboost/train/1662_46-636.png', '/content/final_data_turnboost/train/10916_54-655.png', '/content/final_data_turnboost/train/11157_85-084.png', '/content/final_data_turnboost/train/10337_152-203.png', '/content/final_data_turnboost/train/8041_103-719.png', '/content/final_data_turnboost/train/9015_36-869.png', '/content/final_data_turnboost/train/9500_131-272.png', '/content/final_data_turnboost/train/10172_136-954.png', '/content/final_data_turnboost/train/10666_81-795.png', '/content/final_data_turnboost/train/10839_89-895.png', '/content/final_data_turnboost/train/11787_130-915.png', '/content/final_data_turnboost/train/5906_111-502.png', '/content/final_data_turnboost/train/5225_141-611.png', '/content/final_data_turnboost/train/3149_55-186.png', '/content/final_data_turnboost/train/7418_43-307.png', '/content/final_data_turnboost/train/9956_44-612.png', '/content/final_data_turnboost/train/7440_51-066.png' ...
# ['/content/final_data_turnboost/train/11_110-968.png', '/content/final_data_turnboost/train/12_103-606.png', '/content/final_data_turnboost/train/12_115-288.png', '/content/final_data_turnboost/train/13_81-643.png', '/content/final_data_turnboost/train/14_99-507.png', '/content/final_data_turnboost/train/15_90-004.png', '/content/final_data_turnboost/train/16_103-773.png', '/content/final_data_turnboost/train/16_79-219.png', '/content/final_data_turnboost/train/17_25-079.png', '/content/final_data_turnboost/train/17_103-792.png', '/content/final_data_turnboost/train/21_26-873.png', '/content/final_data_turnboost/train/22_34-031.png', '/content/final_data_turnboost/train/23_43-4.png', '/content/final_data_turnboost/train/23_103-871.png', '/content/final_data_turnboost/train/25_68-915.png', '/content/final_data_turnboost/train/28_103-992.png', '/content/final_data_turnboost/train/29_78-921.png', '/content/final_data_turnboost/train/29_76-092.png', '/content/final_data_turnboost/train/30_78-572.png', '/content/final_data_turnboost/train/30_75-335.png', '/content/final_data_turnboost/train/31_80-778.png', '/content/final_data_turnboost/train/32_77-714.png', '/content/final_data_turnboost/train/33_74-23.png', '/content/final_data_turnboost/train/34_74-423.png', '/content/final_data_turnboost/train/35_104-06.png', '/content/final_data_turnboost/train/36_88-939.png', '/content/final_data_turnboost/train/36_75-598.png', '/content/final_data_turnboost/train/37_104-107.png', '/content/final_data_turnboost/train/38_74-29.png', '/content/final_data_turnboost/train/39_73-639.png', '/content/final_data_turnboost/train/39_104-139.png', '/content/final_data_turnboost/train/40_85-986.png', '/content/final_data_turnboost/train/41_88-827.png', '/content/final_data_turnboost/train/43_104-201.png', '/content/final_data_turnboost/train/44_104-213.png', '/content/final_data_turnboost/train/46_104-221.png', '/content/final_data_turnboost/train/47_78-771.png', '/content/final_data_turnboost/train/48_104-211.png', '/content/final_data_turnboost/train/48_87-607.png', '/content/final_data_turnboost/train/51_104-283.png', '/content/final_data_turnboost/train/54_70-166.png', '/content/final_data_turnboost/train/57_69-949.png', '/content/final_data_turnboost/train/60_104-407.png', '/content/final_data_turnboost/train/61_104-406.png', '/content/final_data_turnboost/train/63_70-347.png', '/content/final_data_turnboost/train/65_69-751.png', '/content/final_data_turnboost/train/65_109-006.png', '/content/final_data_turnboost/train/66_110-032.png', '/content/final_data_turnboost/train/66_104-56.png', '/content/final_data_turnboost/train/67_104-61.png', '/content/final_data_turnboost/train/70_110-069.png', '/content/final_data_turnboost/train/71_109-388.png', '/content/final_data_turnboost/train/71_104-804.png', '/content/final_data_turnboost/train/72_108-616.png', '/content/final_data_turnboost/train/72_70-054.png', '/content/final_data_turnboost/train/73_107-607.png', '/content/final_data_turnboost/train/74_69-94.png', '/content/final_data_turnboost/train/74_106-566.png', '/content/final_data_turnboost/train/75_69-977.png', '/content/final_data_turnboost/train/75_70-219.png', '/content/final_data_turnboost/train/76_104-621.png', '/content/final_data_turnboost/train/77_103-491.png', '/content/final_data_turnboost/train/79_101-528.png', '/content/final_data_turnboost/train/80_70-727.png', '/content/final_data_turnboost/train/82_105-377.png', '/content/final_data_turnboost/train/83_105-46.png', '/content/final_data_turnboost/train/84_70-359.png', '/content/final_data_turnboost/train/85_105-628.png', '/content/final_data_turnboost/train/86_105-7.png', '/content/final_data_turnboost/train/87_105-764.png', '/content/final_data_turnboost/train/89_105-866.png', '/content/final_data_turnboost/train/90_72-404.png', '/content/final_data_turnboost/train/92_93-448.png', '/content/final_data_turnboost/train/93_73-248.png', '/content/final_data_turnboost/train/93_106-206.png' ...
# [110.968, 103.606, 115.288, 81.643, 99.507, 90.004, 103.773, 79.219, 25.079, 103.792, 26.873, 34.031, 43.4, 103.871, 68.915, 103.992, 78.921, 76.092, 78.572, 75.335, 80.778, 77.714, 74.23, 74.423, 104.06, 88.939, 75.598, 104.107, 74.29, 73.639, 104.139, 85.986, 88.827, 104.201, 104.213, 104.221, 78.771, 104.211, 87.607, 104.283, 70.166, 69.949, 104.407, 104.406, 70.347, 69.751, 109.006, 110.032, 104.56, 104.61, 110.069, 109.388, 104.804, 108.616, 70.054, 107.607, 69.94, 106.566, 69.977, 70.219, 104.621, 103.491, 101.528, 70.727, 105.377, 105.46, 70.359, 105.628, 105.7, 105.764, 105.866, 72.404, 93.448, 73.248, 106.206, 91.708, 106.828, 106.913, 156.688, 156.688, 91.051, 132.061, 120.066, 158.83, 158.83, 90.951, 165.0, 165.0, 107.609, 108.042, 108.308, 70.872, 108.503, 71.035, 109.082, 142.706, 140.7, 109.444, 137.025, 109.523, 135.355, 109.682, 130.633, 129.319, 63.358, 126.618, 110.219, 72.368, 51.902, 110.38, 38.09, 124.106, 25.048, 110.447, 120.947, 110.596, 119.918, 72.39, 110.721, 110.882, 116.392, 116.239, 111.068, 111.156, 115.474, 111.238, 111.311, 111.557, 15.538, 15.538, 111.671, 112.201, 111.839, 29.008, 32.976, 36.638, 73.309, 110.284, 40.141, 43.269, 112.133, 112.436, 103.947, 59.088, 60.604, 62.297, 70.734, 78.23, 113.331, 15.0, 15.0, 78.57, 113.794, 80.41, 113.939, 15.0, 15.0, 114.019, 114.3, 114.456, 85.298, 114.537, 96.045, 100.116, 53.457, 114.874, 114.907, 58.796, 116.882, 122.45, 127.441, 131.87, 64.412, 135.768, 139.22, 142.343, 66.95, 144.745, 146.354, 147.61, 115.014, 71.196, 148.477, 115.009, 114.998, 148.461, 114.981, 148.157, 79.859, 137.155, 78.248, 135.405, 114.675, 114.225, 122.002, 113.943, 113.606, 119.758, 112.272, 118.683, 89.139, 88.257, 83.047, 78.261, 110.717, 114.469, 75.159, 102.127, 74.575, 100.161, 110.65, 100.408, 74.028, 109.691, 86.198, 109.54, 109.39, 73.563, 109.191, 73.324, 102.262, 102.522, 109.188, 73.153, 73.003, 98.065, 72.994, 94.652, 112.412, 112.337, 114.56, 116.233, 90.01, 118.706, 119.923, 115.974, 61.138, 73.993, 115.226, 120.968, 59.617, 121.647, 121.987, 58.903, 74.385, 121.262, 74.675, 120.466, 59.649, 61.398, 107.392, 62.499, 112.716, 105.455, 75.829, 109.876, 68.529, 106.803, 76.661, 105.204, 99.287, 96.019, 77.905, 78.468, 68.138, 79.205, 88.299, 87.083, 82.926, 83.759, 84.02, 83.72, 87.752, 72.11, 90.415, 74.932, 102.072, 75.001, 76.659, 95.619, 77.307, 74.137, 92.593, 93.218, 54.418, 52.865, 52.384, 51.931, 92.585, 50.822, 50.695, 93.402, 50.936, 54.533, 55.337, 55.964, 74.847, 56.967, 85.824, 86.647, 68.095, 79.2, 66.586, 66.024, 64.582, 64.679, 87.33, 66.086, 88.178, 101.693, 67.924, 125.994, 132.203, 68.305, 68.643, 153.286, 90.462, 159.902, 159.902, 90.749, 81.62, 77.54, 78.962, 78.56, 94.753, 95.158, 77.867, 86.704, 165.0, 165.0, 77.53, 99.63, 77.716, 100.188, 105.785, 100.746, 102.119, 117.14, 119.018, 78.986, 119.481, 109.04, 112.206, 117.914, 83.143, 120.493, 85.295, 111.171, 125.118, 159.545, 159.545, 89.982, 125.962, 108.66, 126.665, 126.666, 92.858, 145.592, 126.302, 101.688, 125.873, 125.421, 142.764, 124.284, 103.606, 138.889, 123.628, 137.755, 103.202, 122.863, 109.691, 122.095, 136.658, 133.62, 118.876, 118.023, 131.93, 117.199, 131.118, 129.515, 100.089, 100.218, 128.722, 106.048, 127.942, 112.912, 126.722, 111.06, 100.248, 100.08, 99.941, 102.032, 99.773, 99.448, 105.485, 122.905, 122.517, 122.131, 102.291, 99.394, 120.925, 98.878, 119.843, 119.607, 93.07, 119.088, 96.51, 118.831, 95.758, 85.688, 118.407, 94.784, 118.405, 31.404, 30.675, 31.444, 92.284, 32.592, 33.98, 35.759, 92.078, 37.88, 119.602, 92.108, 40.056, 65.601, 42.23, 44.507, 50.97, 53.021, 67.279, 120.866, 54.972, 56.82, 58.564, 121.269, 60.211, 69.453, 121.634, 61.846, 121.981, 122.383, 67.611, 68.996, 73.761, 122.883, 123.619, 123.884, 123.937, 83.799, 123.775, 87.257, 123.562, 84.979, 123.412, 74.395, 122.821, 122.355, 16.886, 16.886, 119.855, 119.49, 119.119, 118.377, 117.263, 116.882, 96.388, 115.761, 95.345, 114.633, 113.523, 111.394, 110.72, 109.392, 109.079, 59.229, 107.818, 1 ...
# ['/content/final_data_turnboost/test/11132_80-54.png', '/content/final_data_turnboost/test/7108_126-789.png', '/content/final_data_turnboost/test/1781_85-092.png', '/content/final_data_turnboost/test/3429_135-644.png', '/content/final_data_turnboost/test/7978_32-845.png', '/content/final_data_turnboost/test/7577_95-001.png', '/content/final_data_turnboost/test/8735_104-116.png', '/content/final_data_turnboost/test/10356_147-555.png', '/content/final_data_turnboost/test/1388_15.png', '/content/final_data_turnboost/test/2704_100-307.png', '/content/final_data_turnboost/test/11575_67-093.png', '/content/final_data_turnboost/test/2969_136-188.png', '/content/final_data_turnboost/test/353_94-607.png', '/content/final_data_turnboost/test/9210_81-845.png', '/content/final_data_turnboost/test/5964_165.png', '/content/final_data_turnboost/test/8563_40-435.png', '/content/final_data_turnboost/test/9094_96-158.png', '/content/final_data_turnboost/test/7431_98-631.png', '/content/final_data_turnboost/test/8565_39-916.png', '/content/final_data_turnboost/test/8564_40-016.png', '/content/final_data_turnboost/test/2593_125-246.png', '/content/final_data_turnboost/test/2533_114-857.png', '/content/final_data_turnboost/test/9184_108-486.png', '/content/final_data_turnboost/test/2266_87-474.png', '/content/final_data_turnboost/test/2674_116-451.png', '/content/final_data_turnboost/test/4490_90-444.png', '/content/final_data_turnboost/test/7836_165.png', '/content/final_data_turnboost/test/7246_95-869.png', '/content/final_data_turnboost/test/8050_80-879.png', '/content/final_data_turnboost/test/5110_73-611.png', '/content/final_data_turnboost/test/9255_142-016.png', '/content/final_data_turnboost/test/6524_84-422.png', '/content/final_data_turnboost/test/11052_108-809.png', '/content/final_data_turnboost/test/6958_155-231.png', '/content/final_data_turnboost/test/4650_91-91.png', '/content/final_data_turnboost/test/1269_81-65.png', '/content/final_data_turnboost/test/3223_123-336.png', '/content/final_data_turnboost/test/1406_23-574.png', '/content/final_data_turnboost/test/9073_119-041.png', '/content/final_data_turnboost/test/2105_34-861.png', '/content/final_data_turnboost/test/863_38-498.png', '/content/final_data_turnboost/test/11908_18-529.png', '/content/final_data_turnboost/test/11038_69-454.png', '/content/final_data_turnboost/test/3329_89.png', '/content/final_data_turnboost/test/2801_110-257.png', '/content/final_data_turnboost/test/8586_61-855.png', '/content/final_data_turnboost/test/9950_42-794.png', '/content/final_data_turnboost/test/4484_97-165.png', '/content/final_data_turnboost/test/3082_95-837.png', '/content/final_data_turnboost/test/4705_154-093.png', '/content/final_data_turnboost/test/1668_69-07.png', '/content/final_data_turnboost/test/3260_126-986.png', '/content/final_data_turnboost/test/4261_33-685.png', '/content/final_data_turnboost/test/1407_156-764.png', '/content/final_data_turnboost/test/1549_147-823.png', '/content/final_data_turnboost/test/2529_67-112.png', '/content/final_data_turnboost/test/2091_75-378.png', '/content/final_data_turnboost/test/8565_121-406.png', '/content/final_data_turnboost/test/154_20-408.png', '/content/final_data_turnboost/test/8831_25-046.png', '/content/final_data_turnboost/test/8483_110-324.png', '/content/final_data_turnboost/test/1299_36-336.png', '/content/final_data_turnboost/test/6356_76-997.png', '/content/final_data_turnboost/test/10621_96-561.png', '/content/final_data_turnboost/test/10206_153-491.png', '/content/final_data_turnboost/test/7880_146-071.png', '/content/final_data_turnboost/test/2632_46-32.png', '/content/final_data_turnboost/test/3617_44-664.png', '/content/final_data_turnboost/test/10307_159-398.png', '/content/final_data_turnboost/test/237_77-777.png', '/content/final_data_turnboost/test/4261_100-657.png', '/content/final_data_turnboost/test/9459_140-494.png', '/content/final_data_turnboost/test/2517_59-432.png', '/content/final_data_turnboost/test/1406_154 ...
# ['/content/final_data_turnboost/test/0_96-068.png', '/content/final_data_turnboost/test/2_78-887.png', '/content/final_data_turnboost/test/4_94-768.png', '/content/final_data_turnboost/test/5_86-256.png', '/content/final_data_turnboost/test/5_97-688.png', '/content/final_data_turnboost/test/18_15.png', '/content/final_data_turnboost/test/18_103-807.png', '/content/final_data_turnboost/test/19_15-577.png', '/content/final_data_turnboost/test/20_103-824.png', '/content/final_data_turnboost/test/20_21-532.png', '/content/final_data_turnboost/test/26_79-52.png', '/content/final_data_turnboost/test/26_103-938.png', '/content/final_data_turnboost/test/26_87-256.png', '/content/final_data_turnboost/test/28_77-048.png', '/content/final_data_turnboost/test/28_79-339.png', '/content/final_data_turnboost/test/154_20-408.png', '/content/final_data_turnboost/test/154_72-888.png', '/content/final_data_turnboost/test/154_111-719.png', '/content/final_data_turnboost/test/155_24-684.png', '/content/final_data_turnboost/test/160_73-607.png', '/content/final_data_turnboost/test/161_46-045.png', '/content/final_data_turnboost/test/162_48-687.png', '/content/final_data_turnboost/test/163_112-309.png', '/content/final_data_turnboost/test/165_55-459.png', '/content/final_data_turnboost/test/170_112-681.png', '/content/final_data_turnboost/test/173_96-232.png', '/content/final_data_turnboost/test/178_35-597.png', '/content/final_data_turnboost/test/178_113-195.png', '/content/final_data_turnboost/test/179_113-264.png', '/content/final_data_turnboost/test/182_113-451.png', '/content/final_data_turnboost/test/183_79-34.png', '/content/final_data_turnboost/test/183_113-505.png', '/content/final_data_turnboost/test/186_113-644.png', '/content/final_data_turnboost/test/187_81-061.png', '/content/final_data_turnboost/test/224_114-958.png', '/content/final_data_turnboost/test/224_147-602.png', '/content/final_data_turnboost/test/225_146-522.png', '/content/final_data_turnboost/test/226_145-241.png', '/content/final_data_turnboost/test/226_114-897.png', '/content/final_data_turnboost/test/227_143-807.png', '/content/final_data_turnboost/test/228_142-251.png', '/content/final_data_turnboost/test/229_114-792.png', '/content/final_data_turnboost/test/229_140-603.png', '/content/final_data_turnboost/test/230_138-894.png', '/content/final_data_turnboost/test/235_130-366.png', '/content/final_data_turnboost/test/236_128-827.png', '/content/final_data_turnboost/test/237_77-777.png', '/content/final_data_turnboost/test/237_127-313.png', '/content/final_data_turnboost/test/239_114-359.png', '/content/final_data_turnboost/test/275_73-213.png', '/content/final_data_turnboost/test/279_73-46.png', '/content/final_data_turnboost/test/280_117-473.png', '/content/final_data_turnboost/test/281_117-018.png', '/content/final_data_turnboost/test/282_116-514.png', '/content/final_data_turnboost/test/347_70-178.png', '/content/final_data_turnboost/test/353_94-607.png', '/content/final_data_turnboost/test/354_58-223.png', '/content/final_data_turnboost/test/355_57-445.png', '/content/final_data_turnboost/test/356_56-776.png', '/content/final_data_turnboost/test/374_81-092.png', '/content/final_data_turnboost/test/376_51-461.png', '/content/final_data_turnboost/test/381_90-72.png', '/content/final_data_turnboost/test/382_53-51.png', '/content/final_data_turnboost/test/384_83-538.png', '/content/final_data_turnboost/test/413_83-569.png', '/content/final_data_turnboost/test/415_64-284.png', '/content/final_data_turnboost/test/416_64-376.png', '/content/final_data_turnboost/test/418_64-527.png', '/content/final_data_turnboost/test/428_66-633.png', '/content/final_data_turnboost/test/430_110-828.png', '/content/final_data_turnboost/test/430_67-129.png', '/content/final_data_turnboost/test/431_67-446.png', '/content/final_data_turnboost/test/432_86-186.png', '/content/final_data_turnboost/test/442_91-148.png', '/content/final_data_turnboost/test/443_165.png', '/content/final_data_turnbo ...
# [96.068, 78.887, 94.768, 86.256, 97.688, 15.0, 103.807, 15.577, 103.824, 21.532, 79.52, 103.938, 87.256, 77.048, 79.339, 20.408, 72.888, 111.719, 24.684, 73.607, 46.045, 48.687, 112.309, 55.459, 112.681, 96.232, 35.597, 113.195, 113.264, 113.451, 79.34, 113.505, 113.644, 81.061, 114.958, 147.602, 146.522, 145.241, 114.897, 143.807, 142.251, 114.792, 140.603, 138.894, 130.366, 128.827, 77.777, 127.313, 114.359, 73.213, 73.46, 117.473, 117.018, 116.514, 70.178, 94.607, 58.223, 57.445, 56.776, 81.092, 51.461, 90.72, 53.51, 83.538, 83.569, 64.284, 64.376, 64.527, 66.633, 110.828, 67.129, 67.446, 86.186, 91.148, 165.0, 80.832, 79.84, 75.227, 121.505, 165.0, 111.905, 123.969, 88.588, 109.946, 121.33, 120.574, 101.867, 134.61, 110.023, 103.625, 125.582, 125.006, 109.043, 118.403, 50.778, 118.38, 118.443, 45.895, 41.419, 37.433, 34.543, 118.647, 32.67, 92.152, 120.209, 46.731, 48.873, 120.569, 122.081, 121.495, 90.883, 91.444, 120.865, 88.449, 87.87, 99.188, 99.052, 120.566, 123.981, 83.725, 124.686, 125.048, 96.921, 82.128, 111.253, 82.846, 66.112, 165.0, 161.078, 82.77, 101.129, 55.76, 76.592, 157.776, 38.498, 157.404, 157.024, 156.639, 62.551, 151.188, 51.468, 150.739, 150.294, 19.397, 143.394, 142.925, 21.889, 23.318, 142.457, 81.183, 141.99, 26.28, 141.525, 141.08, 140.635, 29.681, 140.191, 31.383, 22.474, 23.634, 40.048, 137.965, 24.742, 32.885, 34.56, 134.579, 134.168, 36.433, 126.97, 126.639, 126.311, 125.985, 125.66, 74.857, 123.422, 88.67, 77.561, 86.087, 89.788, 111.487, 81.445, 136.049, 135.572, 104.136, 80.913, 134.077, 132.75, 103.253, 131.063, 101.681, 99.994, 99.997, 124.784, 77.804, 124.961, 99.732, 125.027, 77.225, 125.548, 126.086, 131.098, 47.808, 130.128, 69.525, 128.177, 127.238, 126.304, 90.509, 54.948, 69.323, 67.347, 108.866, 108.447, 66.702, 107.642, 82.693, 105.696, 66.025, 105.345, 86.102, 101.075, 64.071, 100.477, 63.736, 63.41, 56.525, 140.353, 141.197, 141.567, 56.167, 122.426, 32.991, 54.665, 121.12, 27.853, 112.625, 81.65, 112.119, 53.76, 53.711, 15.0, 130.51, 137.432, 53.584, 146.306, 53.578, 156.301, 53.534, 53.51, 53.488, 90.848, 36.336, 91.381, 53.517, 165.0, 53.854, 57.714, 92.365, 58.387, 53.912, 74.961, 67.075, 106.342, 106.959, 69.469, 118.425, 49.318, 119.146, 69.915, 47.212, 15.0, 128.527, 129.651, 71.712, 133.137, 149.271, 17.306, 151.168, 20.365, 152.988, 23.574, 154.956, 156.764, 27.036, 30.522, 165.0, 126.119, 129.104, 84.79, 131.822, 159.314, 158.592, 71.602, 157.017, 156.158, 110.076, 147.625, 100.755, 147.823, 109.347, 107.247, 159.183, 145.763, 145.285, 144.78, 147.522, 132.566, 132.011, 147.055, 146.589, 138.397, 138.026, 137.651, 137.279, 136.909, 120.229, 132.125, 131.819, 120.145, 131.21, 129.489, 129.222, 128.956, 123.161, 69.07, 115.892, 42.211, 122.784, 42.34, 42.782, 69.116, 115.244, 122.406, 43.39, 44.151, 122.217, 69.366, 114.838, 108.079, 80.897, 117.562, 107.641, 81.758, 84.0, 115.982, 115.862, 84.331, 105.274, 115.502, 84.421, 115.382, 104.911, 104.601, 98.217, 81.997, 115.978, 82.207, 97.629, 85.092, 106.887, 95.951, 95.849, 103.283, 86.387, 111.911, 111.731, 93.569, 92.84, 90.199, 92.01, 91.589, 91.417, 90.874, 84.546, 71.078, 116.218, 72.276, 83.128, 83.0, 15.0, 84.325, 76.111, 75.659, 73.368, 69.248, 126.158, 126.767, 72.94, 75.378, 25.18, 25.857, 26.574, 34.861, 35.521, 76.373, 36.822, 46.339, 47.401, 70.657, 103.85, 56.677, 79.968, 57.042, 57.401, 32.774, 87.474, 30.394, 29.007, 28.29, 28.718, 29.543, 30.501, 31.643, 85.343, 90.124, 82.842, 75.504, 75.718, 75.876, 80.46, 77.306, 82.406, 79.766, 78.023, 78.982, 78.677, 78.179, 80.764, 76.872, 118.949, 93.723, 127.794, 128.798, 90.394, 111.916, 112.059, 57.181, 55.875, 89.64, 59.432, 113.966, 47.858, 114.04, 47.948, 114.485, 67.112, 51.259, 88.076, 114.857, 140.058, 49.577, 125.246, 46.575, 125.464, 39.501, 126.085, 140.716, 89.265, 126.313, 38.995, 140.769, 38.244, 126.537, 37.786, 129.579, 26.0, 136.222, 26.181, 80.184, 130.181, 28.448, 29.579, 130.334, 30.843, 130.696, 129.8, 43.422, 46.32, 128.758, 130.962, 60.89, ...

# %% [markdown]
# ## Part 4: Loading in the images
#
# The below code is outside the scope of this course but a brief explanation is provided nevertheless.
#
# ### Dataset Creation
# The dataset creation involves the creation of what is known as a dataset pipeline. All this is, is a sequence of transformations applied one after the other that manipulate the data in different ways.
# 1. from_tensor_slices. We load in the images and the steering angles into the dataset
# 2. repeat. Simply loop the dataset for infinity when we get to the end. This is done to make sure our network never runs out of data. For instance we train on batches of 32 if we had 52 images we would run out of data.
# 3. shuffle. Self explanatory makes sure we don't feed network ordered data as this can cause weird issues. Note we don't need to do this with our validation data so we might as well save the unnecessary operation by excluding shuffle.
# 4. batch. Tell the dataset that when we fetch a item from it is should return a number of items. This is more efficient as you almost certainly have enough RAM to handle more than 1 image.
# 5. Prefetch. Tell the dataset that when it's not doing anything it should automatically be loading data into RAM in the background. This results in huge performance increases as when we're training we don't have to sit around waiting for the dataset to load the images.

# %%
import matplotlib.pyplot as plt # import matplotlib for plotting
import tensorflow as tf
import cv2 as cv
from google.colab.patches import cv2_imshow
import numpy as np
import tqdm

train_data = []
test_data = []

tqdm.tqdm.write("Loading training data")
# load the images and steering angles into numpy arrays
for path in tqdm.tqdm(train_img):
    img = cv.imread(path) # read the image
    hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)
    # mask the image to get only the desired colors
    mask = cv.inRange(hsv, (36, 0, 0), (70, 255,255))
    array = np.array(mask, dtype=np.float32)
    train_data.append(array)

tqdm.tqdm.write("Loading test data")
# loading the testing data
for path in tqdm.tqdm(test_img):
    img = cv.imread(path) # read the image
    hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)
    # mask the image to get only the desired colors
    mask = cv.inRange(hsv, (36, 0, 0), (70, 255,255))
    array = np.array(mask, dtype=np.float32)
    test_data.append(array)

# create a dataset from the training data and make a data pipeline
train_ds = tf.data.Dataset.from_tensor_slices((train_data, train_steer)) # create a dataset from the image paths and steering angles
train_ds = train_ds.repeat()
train_ds = train_ds.shuffle(buffer_size=len(train_img)) # shuffle the dataset
train_ds = train_ds.batch(BATCH_SIZE) # batch the dataset
train_ds = train_ds.prefetch(tf.data.experimental.AUTOTUNE) # prefetch the dataset to improve performance

# create a dataset from the testing data and make a data pipeline
test_ds = tf.data.Dataset.from_tensor_slices((test_data, test_steer)) # create a dataset from the image paths and steering angles
test_ds = test_ds.repeat() # repeat the dataset
test_ds = test_ds.batch(BATCH_SIZE) # batch the dataset
test_ds = test_ds.prefetch(tf.data.experimental.AUTOTUNE) # prefetch the dataset to improve performance

# output the first 16 images and steering angles from the dataset
fig, axs = plt.subplots(4, 4, figsize=(8, 8))
# add title to the figure
fig.suptitle('Training Data')
fig.tight_layout()

imgs, steer = next(iter(train_ds)) # get the first batch of images and steering angles

for i in range(16):
    axs[i//4, i%4].axis('off')
    axs[i//4, i%4].imshow(imgs[i])
    axs[i//4, i%4].set_title(round(steer[i].numpy(), 2))
plt.tight_layout()
plt.show()
# Out:
# Loading training data
# 100%|██████████| 8948/8948 [00:03<00:00, 2495.94it/s]
# Loading test data
# 100%|██████████| 2069/2069 [00:00<00:00, 2916.83it/s]

# %% [markdown]
# ## Part 5: This is where you will create your model
# try modifying the layers to try to get the lowest mse score,
# This is going to require some trial and error so make sure you spend some time experimenting.

# %%
import numpy as np
np.random.seed(1337)  # for reproducibility
import keras as ks
from keras.models import Sequential
from keras.layers import Dense, InputLayer, Conv2D, Flatten, MaxPool2D, Dropout
from keras.optimizers import Adam
import matplotlib.pyplot as plt

# a sequential model is a model that is made up of layers
model = Sequential()
# the input layer is the first layer in the model. You shouldn't need to change this.
model.add(InputLayer(input_shape=(66, 100, 1), batch_size=BATCH_SIZE))

# try modifying the number of nodes in the hidden layer to see how it affects the model
# you can also try changing the activation function to see how it affects the model
# adding more layers to the model may also help you to acheive your score

# in this lab you also have access to the Conv2D layer and MaxPool2D layer. Try modifying these to see how they affect the model.
model.add(Conv2D(32, (3, 3), activation='relu'))  # conv layer 32 filters size 3x3
model.add(MaxPool2D(pool_size=(2, 2)))  # pooling layer size 3x3
model.add(Conv2D(64, (3, 3), activation='relu'))  # conv filters size 3x3
model.add(MaxPool2D(pool_size=(2, 2)))  # pooling layer size
model.add(Conv2D(128, (3, 3), activation='relu'))  # conv filters size
model.add(MaxPool2D(pool_size=(2, 2)))  # pooling layer size
model.add(Flatten())  # flatten layer
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='linear'))

optimizer = Adam(learning_rate=0.005)  # try changing the learning rate to see how it affects the model
model.compile(optimizer=optimizer, loss='mse')  # we will keep track of the mean squared error

print(model.summary())  # print a summary of the model

# Train the model without EarlyStopping
epoch = 15
hist = model.fit(train_ds,
                 steps_per_epoch=len(train_img) // BATCH_SIZE,
                 validation_data=test_ds,
                 validation_steps=len(test_img) // BATCH_SIZE,
                 epochs=epoch)  # EarlyStopping removed

# let's plot the model's history
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
# plt.plot(np.log(hist.history['loss']))       # log scale
# plt.plot(np.log(hist.history['val_loss']))   # log scale
plt.title('model mean squared error loss')
plt.ylabel('mean squared error loss')
plt.xlabel('epoch')
plt.legend(['training set', 'validation set'], loc='upper right')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (32, 64, 98, 32)       │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (32, 32, 49, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (32, 30, 47, 64)       │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (32, 15, 23, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (32, 13, 21, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (32, 6, 10, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (32, 7680)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (32, 32)               │       245,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (32, 16)               │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (32, 1)                │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 339,009 (1.29 MB)
#  Trainable params: 339,009 (1.29 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/15
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - loss: 2954.3855 - val_loss: 87.5176
# Epoch 2/15
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 67.0697 - val_loss: 64.5592
# Epoch 3/15
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 46.9060 - val_loss: 51.8719
# Epoch 4/15
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 31.4407 - val_loss: 54.5304
# Epoch 5/15
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 23.2249 - val_loss: 58.1790
# Epoch 6/15
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 23.6056 - val_loss: 44.8718
# Epoch 7/15
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 24.5087 - val_loss: 35.8643
# Epoch 8/15
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 19.8813 - val_loss: 38.8005
# Epoch 9/15
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 15.6183 - val_loss: 33.3135
# Epoch 10/15
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 13.3712 - val_loss: 30.0310
# Epoch 11/15
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 16.5943 - val_loss: 38.3677
# Epoch 12/15
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 14.4487 - val_loss: 44.4040
# Epoch 13/15
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 16.8070 - val_loss: 27.1086
# Epoch 14/15
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 15.9090 - val_loss: 33.2054
# Epoch 15/15
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 14.5400 - val_loss: 34.2111

# %% [markdown]
# Have a look at the graph generated below. With this you can get an idea of whether your model is training well. You should want to see both lines trend downwards.

# %% [markdown]
# ## Part 6: Test the model
# We'll now output 16 images with the predicted steering angles along with the actual steering angles

# %%
# output the first 16 images and steering angles from the test dataset then predict the steering angle for the images
fig, axs = plt.subplots(4, 4, figsize=(8, 8))
# add title to the figure
fig.suptitle('Training Data')
fig.tight_layout()

imgs, steer = next(iter(test_ds)) # get the first batch of images and steering angles

for i in range(16):
    axs[i//4, i%4].axis('off')
    axs[i//4, i%4].imshow(imgs[i])
    axs[i//4, i%4].set_title(round(steer[i].numpy(), 2))
    predicted = model(imgs[i].numpy().reshape(1, 66, 100, 1)) # predict the steering angle for the image
    axs[i//4, i%4].set_title("Predicted: " + str(np.round(predicted[0][0].numpy(), 2)) + "\n Actual: " + str(round(steer[i].numpy(), 2)))
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 7: export your model
# Once you are happy with your model you can export it by running the code below.
# This will save your model as model.h5 and model.onnx.
#
# The ".h5" model is used for the physical PiCar and the ".onnx" model is used for the PiCar Simulator. You can change this to be more descriptive. I also recommend saving multiple models with different training settings so you have a couple to experiment with.

# %%
# !pip install onnx
# !pip install tf2onnx
# Out:
# Collecting onnx
#   Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.12/dist-packages (from onnx) (2.0.2)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx) (5.29.6)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx) (0.5.4)
# Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 102.7 MB/s eta 0:00:00
# Installing collected packages: onnx
# Successfully installed onnx-1.21.0
# Collecting tf2onnx
#   Downloading tf2onnx-1.17.0-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.12/dist-packages (from tf2onnx) (2.0.2)
# Requirement already satisfied: onnx>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from tf2onnx) (1.21.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from tf2onnx) (2.32.4)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.12/dist-packages (from tf2onnx) (25.12.19)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.12/dist-packages (from tf2onnx) (5.29.6)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.14.0->tf2onnx) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.14.0->tf2onnx) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->tf2onnx) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->tf2onnx) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->tf2onnx) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->tf2onnx) (2026.2.25)
# Downloading tf2onnx-1.17.0-py3-none-any.whl (839 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 839.1/839.1 kB 54.8 MB/s eta 0:00:00
# Installing collected packages: tf2onnx
# Successfully installed tf2onnx-1.17.0

# %%
import onnx
import tf2onnx
import tensorflow as tf

model_name = "conv_model" # change the name to something more descriptive if you want
model.save(model_name + '.keras')
model.save(model_name + ".h5")
model.output_names = ['output']
input_signature = [tf.TensorSpec([None, 66, 100, 1], tf.float32, name='input')]

onnx_model, _ = tf2onnx.convert.from_keras(model, input_signature=input_signature, opset=13)

onnx.save(onnx_model, model_name + ".onnx")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
